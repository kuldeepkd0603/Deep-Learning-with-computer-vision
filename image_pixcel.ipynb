# %%
import cv2

# %%
image = cv2.imread('/content/Kuldeep_verma.jpg')

print(image.shape)
# Out:
# (1708, 1348, 3)

# %%
print(image)
# Out:
# [[[108 139 148]
#   [109 140 149]
#   [109 140 149]
#   ...
#   [169 172 180]
#   [170 173 181]
#   [170 173 181]]
#
#  [[108 139 148]
#   [109 140 149]
#   [109 140 149]
#   ...
#   [169 172 180]
#   [170 173 181]
#   [170 173 181]]
#
#  [[109 140 149]
#   [109 140 149]
#   [107 140 149]
#   ...
#   [169 172 180]
#   [169 172 180]
#   [170 173 181]]
#
#  ...
#
#  [[ 81 129 135]
#   [ 82 130 136]
#   [ 81 129 135]
#   ...
#   [135 154 162]
#   [135 154 162]
#   [135 154 162]]
#
#  [[ 81 129 135]
#   [ 82 130 136]
#   [ 81 129 135]
#   ...
#   [136 155 163]
#   [136 155 163]
#   [135 154 162]]
#
#  [[ 79 127 133]
#   [ 80 128 134]
#   [ 79 127 133]
#   ...
#   [135 154 162]
#   [135 154 162]
#   [135 154 162]]]

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
gray_image
# Out:
# array([[138, 139, 139, ..., 174, 175, 175],
#        [138, 139, 139, ..., 174, 175, 175],
#        [139, 139, 139, ..., 174, 174, 175],
#        ...,
#        [125, 126, 125, ..., 154, 154, 154],
#        [125, 126, 125, ..., 155, 155, 154],
#        [123, 124, 123, ..., 154, 154, 154]], dtype=uint8)

# %%
cv2.imwrite('grayscale_image.jpg', gray_image)
# Out:
# True
